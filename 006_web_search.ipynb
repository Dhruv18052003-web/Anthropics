# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
web_search_schema = {
    "type": "web_search_20250305",
    "name": "web_search",
    "max_uses": 5
}

# %%
messages = []
add_user_message(
    messages,
    """
    What is the best excersice for gaining leg muscle?
    """,
)
response = chat(messages, tools = [web_search_schema])
response.content
# Out:
# [TextBlock(citations=None, text="The best exercises for gaining leg muscle are compound movements that target multiple muscle groups. Here are the top choices:\n\n## **Squats** (Back Squats or Front Squats)\nOften considered the king of leg exercises, squats work your quadriceps, hamstrings, glutes, and calves while also engaging your core. They allow you to lift heavy weight and stimulate significant muscle growth.\n\n## **Deadlifts** (Conventional or Romanian)\nDeadlifts are excellent for building hamstrings, glutes, and lower back strength. Romanian deadlifts specifically target the hamstrings and glutes with constant tension.\n\n## **Lunges**\nLunges work each leg independently, helping to correct muscle imbalances while targeting quads, hamstrings, and glutes. Variations include walking lunges, reverse lunges, and Bulgarian split squats.\n\n## **Leg Press**\nThis machine-based exercise allows you to safely lift heavy weight while targeting the quads, hamstrings, and glutes. It's especially useful when you're fatigued from squats or want to add extra volume.\n\n## **Bulgarian Split Squats**\nA unilateral exercise that intensely targets the quads and glutes while improving balance and addressing strength imbalances between legs.\n\n## Key Tips for Leg Muscle Growth:\n- **Progressive overload**: Gradually increase weight, reps, or sets over time\n- **Train 2-3 times per week**: Allow adequate recovery between sessions\n- **Use proper form**: Prevents injury and ensures maximum muscle engagement\n- **Eat sufficient protein and calories**: Muscle growth requires proper nutrition\n- **Include variety**: Combine different exercises to target all leg muscles\n\nIf you had to choose just one exercise, **squats** would be the most effective overall for leg muscle development, but combining multiple exercises will give you the best results.", type='text')]
